# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os

# %%
# %load_ext autoreload
# %autoreload 2
from streamfindml import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 from streamfindml import utils
#
# ModuleNotFoundError: No module named 'streamfindml'

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import streamgoggles

# %%
dp2df = streamgoggles.utils.get_DC2_data()

# %%
dp2df.columns
# Out:
# Index(['coord_ra', 'coord_dec', 'u_psfMag', 'g_psfMag', 'r_psfMag', 'i_psfMag',
#        'z_psfMag', 'y_psfMag', 'u_psfMagErr', 'g_psfMagErr', 'r_psfMagErr',
#        'i_psfMagErr', 'z_psfMagErr', 'y_psfMagErr', 'refExtendedness', 'ebv'],
#       dtype='str')
